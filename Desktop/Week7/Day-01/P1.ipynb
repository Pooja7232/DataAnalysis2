# %% [markdown]
# # 1. Importing Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("loan_approved.csv")
print(df.info())
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# None
# ...

# %% [markdown]
# int float category object boolean datetime

# %%
print(len(df['Loan_ID'].unique())) #-- Categorical(Ordinal)
print(df['Loan_ID'].unique())
print(len(df['Loan_ID']))
# Out:
# 614
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
print(len(df['Gender'].unique())) #-- Categorical(Nominal)
print(df['Gender'].unique())
print(len(df['Gender']))
# Out:
# 3
# ['Male' 'Female' nan]
# 614

# %%
print(len(df['Married'].unique())) #-- Categorical(Nominal)
print(df['Married'].unique())
print(len(df['Married']))
# Out:
# 3
# ['No' 'Yes' nan]
# 614

# %%
print(len(df['Dependents'].unique())) #-- Numerical(Discrete)
print(df['Dependents'].unique())
print(len(df['Dependents']))
# Out:
# 5
# ['0' '1' '2' '3+' nan]
# 614

# %%
print(len(df['Education'].unique())) #-- Categorical(Nominal)
print(df['Education'].unique())
print(len(df['Education']))
# Out:
# 2
# ['Graduate' 'Not Graduate']
# 614

# %%
print(len(df['Self_Employed'].unique())) #-- Categorical(Nominal)
print(df['Self_Employed'].unique())
print(len(df['Self_Employed']))
# Out:
# 3
# ['No' 'Yes' nan]
# 614

# %%
print(len(df['ApplicantIncome'].unique())) #-- Numerical(Continuous)
print(df['ApplicantIncome'].unique())
print(len(df['ApplicantIncome']))
# Out:
# 505
# [ 5849  4583  3000  2583  6000  5417  2333  3036  4006 12841  3200  2500
#   3073  1853  1299  4950  3596  3510  4887  2600  7660  5955  3365  3717
#   9560  2799  4226  1442  3750  4166  3167  4692  3500 12500  2275  1828
#   3667  3748  3600  1800  2400  3941  4695  3410  5649  5821  2645  4000
#   1928  3086  4230  4616 11500  2708  2132  3366  8080  3357  3029  2609
#   4945  5726 10750  7100  4300  3208  1875  4755  5266  1000  3333  3846
#   2395  1378  3988  2366  8566  5695  2958  6250  3273  4133  3620  6782
#   2484  1977  4188  1759  4288  4843 13650  4652  3816  3052 11417  7333
#   3800  2071  5316  2929  3572  7451  5050 14583  2214  5568 10408  5667
#   2137  2957  3692 23803  3865 10513  6080 20166  2014  2718  3459  4895
#   3316 14999  4200  5042  6950  2698 11757  2330 14866  1538 10000  4860
#   6277  2577  9166  2281  3254 39999  9538  2980  1863  7933  3089  4167
#   9323  3707  2439  2237  8000  1820 51763  3522  5708  4344  3497  2045
# ...

# %%
print(len(df['CoapplicantIncome'].unique())) #-- Numerical(Continuous)
print(df['CoapplicantIncome'].unique())
print(len(df['CoapplicantIncome']))
# Out:
# 287
# [0.00000000e+00 1.50800000e+03 2.35800000e+03 4.19600000e+03
#  1.51600000e+03 2.50400000e+03 1.52600000e+03 1.09680000e+04
#  7.00000000e+02 1.84000000e+03 8.10600000e+03 2.84000000e+03
#  1.08600000e+03 3.50000000e+03 5.62500000e+03 1.91100000e+03
#  1.91700000e+03 2.92500000e+03 2.25300000e+03 1.04000000e+03
#  2.08300000e+03 3.36900000e+03 1.66700000e+03 3.00000000e+03
#  2.06700000e+03 1.33000000e+03 1.45900000e+03 7.21000000e+03
#  1.66800000e+03 1.21300000e+03 2.33600000e+03 3.44000000e+03
#  2.27500000e+03 1.64400000e+03 1.16700000e+03 1.59100000e+03
#  2.20000000e+03 2.25000000e+03 2.85900000e+03 3.79600000e+03
#  3.44900000e+03 4.59500000e+03 2.25400000e+03 3.06600000e+03
#  1.87500000e+03 1.77400000e+03 4.75000000e+03 3.02200000e+03
#  4.00000000e+03 2.16600000e+03 1.88100000e+03 2.53100000e+03
#  2.00000000e+03 2.11800000e+03 4.16700000e+03 2.90000000e+03
#  5.65400000e+03 1.82000000e+03 2.30200000e+03 9.97000000e+02
# ...

# %%
sns.histplot(df['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
print(len(df['LoanAmount'].unique())) #-- Numerical(Continuous)
print(df['LoanAmount'].unique())
print(len(df['LoanAmount']))
# Out:
# 204
# [ nan 128.  66. 120. 141. 267.  95. 158. 168. 349.  70. 109. 200. 114.
#   17. 125. 100.  76. 133. 115. 104. 315. 116. 112. 151. 191. 122. 110.
#   35. 201.  74. 106. 320. 144. 184.  80.  47.  75. 134.  96.  88.  44.
#  286.  97. 135. 180.  99. 165. 258. 126. 312. 136. 172.  81. 187. 113.
#  176. 130. 111. 167. 265.  50. 210. 175. 131. 188.  25. 137. 160. 225.
#  216.  94. 139. 152. 118. 185. 154.  85. 259. 194.  93. 370. 182. 650.
#  102. 290.  84. 242. 129.  30. 244. 600. 255.  98. 275. 121.  63. 700.
#   87. 101. 495.  67.  73. 260. 108.  58.  48. 164. 170.  83.  90. 166.
#  124.  55.  59. 127. 214. 240.  72.  60. 138.  42. 280. 140. 155. 123.
#  279. 192. 304. 330. 150. 207. 436.  78.  54.  89. 143. 105. 132. 480.
#   56. 159. 300. 376. 117.  71. 490. 173.  46. 228. 308. 236. 570. 380.
#  296. 156. 103.  45.  65.  53. 360.  62. 218. 178. 239. 405. 148. 190.
#  149. 153. 162. 230.  86. 234. 246. 500. 186. 119. 107. 209. 208. 243.
# ...

# %%
print(len(df['Loan_Amount_Term'].unique())) #-- Numerical(Discrete)
print(df['Loan_Amount_Term'].unique())
print(len(df['Loan_Amount_Term']))
# Out:
# 11
# [360. 120. 240.  nan 180.  60. 300. 480.  36.  84.  12.]
# 614

# %%
print(len(df['Credit_History'].unique())) #-- Numerical(Discrete)
print(df['Credit_History'].unique())
print(len(df['Credit_History']))
# Out:
# 3
# [ 1.  0. nan]
# 614

# %%
print(len(df['Property_Area'].unique())) #-- Categorical(Nominal)
print(df['Property_Area'].unique())
print(len(df['Property_Area']))
# Out:
# 3
# ['Urban' 'Rural' 'Semiurban']
# 614

# %%
print(len(df['Loan_Status (Approved)'].unique())) #-- Categorical(Nominal)
print(df['Loan_Status (Approved)'].unique())
print(len(df['Loan_Status (Approved)']))
# Out:
# 2
# ['Y' 'N']
# 614

# %% [markdown]
# # 2. Categorizing Data into Categorical & Numerical

# %% [markdown]
# Loan_ID --> Categorical()
#
# Gender --> Categorical
#
# Married --> Categorical
#
# Dependents --> Numerical
#
# Education --> Categorical
#
# Self_Employed --> Categorical
#
# ApplicantIncome --> Numerical
#
# CoapplicantIncome --> Numerical
#
# LoanAmount --> Numerical
#
# Loan_Amount_Term --> Numerical
#
# Credit_History --> Numerical
#
# Property_Area --> Categorical
#
# Loan_Status(Approved) --> Categorical

# %%
df['Loan_ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
print(df['Gender'].isnull().sum())
sns.countplot(x=df["Gender"],hue=df['Loan_Status (Approved)'])
plt.show()
# Out:
# 0

# %%
df['Married'].isnull().sum()
# Out:
# np.int64(3)

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
print(df['Married'].isnull().sum())
sns.countplot(x=df["Married"],hue=df['Loan_Status (Approved)'])
# Out:
# 0
# <Axes: xlabel='Married', ylabel='count'>

# %%
df['Dependents'].isnull().sum()
sns.countplot(x='Dependents',data=df,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
print(df['Dependents'].isnull().sum())
# Out:
# 0

# %%
df['Education'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Self_Employed'].isnull().sum()
sns.countplot(x=df["Self_Employed"])
plt.show()

# %%
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
print(df['Self_Employed'].isnull().sum())
# Out:
# 0

# %%
df['ApplicantIncome'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['CoapplicantIncome'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['LoanAmount'].isnull().sum()
sns.boxplot(x=df["Dependents"], y=df["LoanAmount"])
# Out:
# <Axes: xlabel='Dependents', ylabel='LoanAmount'>

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
print(df['LoanAmount'].isnull().sum())
# Out:
# 0

# %%
df['Loan_Amount_Term'].isnull().sum()
sns.countplot(x=df["Loan_Amount_Term"])
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='count'>

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
print(df['Loan_Amount_Term'].isnull().sum())
# Out:
# 0

# %%
df['Credit_History'].isnull().sum()
sns.countplot(x=df["Credit_History"], hue=df["Loan_Status (Approved)"])
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].median())
print(df['Credit_History'].isnull().sum())
# Out:
# 0

# %%
df['Property_Area'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Loan_Status (Approved)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Credit_History'].value_counts(0)
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
mean=df['ApplicantIncome'].mean()

# %%
sd=df['ApplicantIncome'].std()

# %%
print(mean)
print(sd)
# Out:
# 5403.459283387622
# 6109.041673387174

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
print(df['ApplicantIncome'].max())
print(df['ApplicantIncome'].min())
# Out:
# 81000
# 150

# %%
sk=df['ApplicantIncome'].skew()
ku=df['ApplicantIncome'].kurt()
print(sk)
print(ku)
# Out:
# 6.539513113994625
# 60.54067593369113
